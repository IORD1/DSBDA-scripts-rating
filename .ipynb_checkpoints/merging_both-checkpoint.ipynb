# %%
import pandas as pd

# %%
df = pd.read_csv('movie_data.csv')

# %%
dfr = pd.read_csv("rating_mean_all.csv")

# %%
df.shape
# Out:
# (44425, 19)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1            0
# Unnamed: 0              0
# adult                   0
# budget                  0
# genres                  0
# id                      0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %%
dfr.rename(columns = {'movieId':'id'}, inplace = True)

# %%
dfr.dtypes
# Out:
# id          int64
# rating    float64
# dtype: object

# %%
df.dtypes
# Out:
# Unnamed: 0.1              int64
# Unnamed: 0                int64
# adult                      bool
# budget                    int64
# genres                   object
# id                        int64
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                 float64
# runtime                 float64
# spoken_languages         object
# title                    object
# vote_average            float64
# vote_count              float64
# dtype: object

# %%
df
# Out:
#        Unnamed: 0.1  Unnamed: 0  adult    budget  \
# 4319           4342        4342  False         0
# 12907         12947       12947  False         0
# 17               17          17  False   4000000
# 472             474         474  False         0
# 255             256         256  False  11000000
# ...             ...         ...    ...       ...
# 43983         45000       45000  False         0
# 44057         45078       45078  False         0
# 44243         45273       45273  False         0
# 21705         21891       21891  False         0
# 20032         20189       20189  False         0
#
#                                                   genres      id  \
# 4319   [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...       2
# 12907  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...       3
# 17     [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...       5
# 472    [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...       6
# 255    [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...      11
# ...                                                  ...     ...
# 43983                [{'id': 99, 'name': 'Documentary'}]  464819
# 44057  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...  465044
# 44243                      [{'id': 18, 'name': 'Drama'}]  467731
# 21705  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...  468343
# 20032  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...  469172
#
#       original_language                                   original_title  \
# 4319                 fi                                            Ariel
# 12907                fi                             Varjoja paratiisissa
# 17                   en                                       Four Rooms
# 472                  en                                   Judgment Night
# 255                  en                                        Star Wars
# ...                 ...                                              ...
# 43983                en  The Making of 'The Terminator': A Retrospective
# 44057                en                                        Abduction
# 44243                en                      Tragedy in a Temporary Town
# 21705                fi                         Silja - nuorena nukkunut
# 20032                pt                 Manoel dans l'île des merveilles
#
#                                                 overview  popularity  \
# 4319   Taisto Kasurinen is a Finnish coal miner whose...    3.860491
# 12907  An episode in the life of Nikander, a garbage ...    2.292110
# 17     It's Ted the Bellhop's first night on the job....    9.026586
# 472    While racing to a boxing match, Frank, Mike, J...    5.538671
# 255    Princess Leia is captured and held hostage by ...   42.149697
# ...                                                  ...         ...
# 43983  An interview session with Arnold Schwarzenegge...    0.000001
# 44057  A horror comedy spoofing conspiracy theory mov...    0.281008
# 44243  Fifteen-year-old girl Dotty Fisher is assaulte...    0.001189
# 21705  In the 1910s, beautiful young Silja loses both...    0.001202
# 20032  Manuel is a young boy who travels from long ag...    0.001097
#
#                                     production_companies  \
# 4319   [{'name': 'Villealfa Filmproduction Oy', 'id':...
# 12907  [{'name': 'Villealfa Filmproduction Oy', 'id':...
# 17     [{'name': 'Miramax Films', 'id': 14}, {'name':...
# 472    [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 255    [{'name': 'Lucasfilm', 'id': 1}, {'name': 'Twe...
# ...                                                  ...
# 43983                                                 []
# 44057                                                 []
# 44243                                                 []
# 21705                                                 []
# 20032  [{'name': "Institut National de l'Audiovisuel ...
#
#                                     production_countries release_date  \
# 4319           [{'iso_3166_1': 'FI', 'name': 'Finland'}]   1988-10-21
# 12907          [{'iso_3166_1': 'FI', 'name': 'Finland'}]   1986-10-16
# 17     [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-09
# 472    [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...   1993-10-15
# 255    [{'iso_3166_1': 'US', 'name': 'United States o...   1977-05-25
# ...                                                  ...          ...
# 43983  [{'iso_3166_1': 'US', 'name': 'United States o...   1992-01-01
# 44057   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-28
# 44243  [{'iso_3166_1': 'US', 'name': 'United States o...   1956-02-19
# 21705          [{'iso_3166_1': 'FI', 'name': 'Finland'}]   1956-01-01
# 20032  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   1984-08-02
#
#            revenue  runtime  \
# 4319           0.0     69.0
# 12907          0.0     76.0
# 17       4300000.0     98.0
# 472     12136938.0    110.0
# 255    775398007.0    121.0
# ...            ...      ...
# 43983          0.0     18.0
# 44057          0.0     90.0
# 44243          0.0     60.0
# 21705          0.0     87.0
# 20032          0.0    130.0
#
#                                         spoken_languages  \
# 4319   [{'iso_639_1': 'fi', 'name': 'suomi'}, {'iso_6...
# 12907  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 17              [{'iso_639_1': 'en', 'name': 'English'}]
# 472             [{'iso_639_1': 'en', 'name': 'English'}]
# 255             [{'iso_639_1': 'en', 'name': 'English'}]
# ...                                                  ...
# 43983           [{'iso_639_1': 'en', 'name': 'English'}]
# 44057           [{'iso_639_1': 'en', 'name': 'English'}]
# 44243           [{'iso_639_1': 'en', 'name': 'English'}]
# 21705                                                 []
# 20032  [{'iso_639_1': 'pt', 'name': 'Português'}, {'i...
#
#                                                  title  vote_average  \
# 4319                                             Ariel           7.1
# 12907                              Shadows in Paradise           7.1
# 17                                          Four Rooms           6.5
# 472                                     Judgment Night           6.4
# 255                                          Star Wars           8.1
# ...                                                ...           ...
# 43983  The Making of 'The Terminator': A Retrospective           0.0
# 44057                                        Abduction           0.0
# 44243                      Tragedy in a Temporary Town           0.0
# 21705                         Silja - nuorena nukkunut           0.0
# 20032                  Manuel on the Island of Wonders           0.0
#
#        vote_count
# 4319         44.0
# 12907        35.0
# 17          539.0
# 472          79.0
# 255        6778.0
# ...           ...
# 43983         0.0
# 44057         0.0
# 44243         0.0
# 21705         0.0
# 20032         0.0
#
# [44425 rows x 19 columns]

# %%
dfr.sort_values('id',inplace=True)

# %%
df['id'].nunique()
# Out:
# 44395

# %%
dfr['id'].nuniqueue()
# Out:
# 45115

# %%
dfm = pd.merge(df, dfr, on="id")

# %%
dfm2 = pd.merge(df, dfr, on='id',  how='left')

# %%
dfm.shape
# Out:
# (7434, 20)

# %%
dfm.to_csv('movie_&_rating.csv')

# %%
dfm2.isnull().sum()
# Out:
# adult                       0
# budget                      0
# genres                      0
# id                          0
# original_language          11
# original_title              0
# overview                  954
# popularity                  5
# production_companies        4
# production_countries        3
# release_date               87
# revenue                     6
# runtime                   263
# spoken_languages            6
# tagline                 24986
# title                      64
# vote_average                9
# vote_count                  9
# rating                  37897
# dtype: int64

# %%
dfr
# Out:
#            id    rating
# 0           1  3.888157
# 1           2  3.236953
# 2           3  3.175550
# 3           4  2.875713
# 4           5  3.079565
# ...       ...       ...
# 45110  176267  4.000000
# 45111  176269  3.500000
# 45112  176271  5.000000
# 45113  176273  1.000000
# 45114  176275  3.000000
#
# [45115 rows x 2 columns]

# %%
dfm2.shape
# Out:
# (45466, 19)

# %%
dfm
# Out:
#       Unnamed: 0.1  Unnamed: 0  adult    budget  \
# 0                0           0  False  30000000
# 1                1           1  False  65000000
# 2                5           5  False  60000000
# 3                9           9  False  58000000
# 4               14          14  False  98000000
# ...            ...         ...    ...       ...
# 7429         45406       45406  False         0
# 7430         45433       45433  False         0
# 7431         45436       45436  False         0
# 7432         45450       45450  False         0
# 7433         45462       45462  False         0
#
#                                                  genres      id  \
# 0     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1     [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2     [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...     949
# 3     [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...     710
# 4     [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...    1408
# ...                                                 ...     ...
# 7429  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...   98604
# 7430  [{'id': 10402, 'name': 'Music'}, {'id': 35, 'n...    5589
# 7431  [{'id': 28, 'name': 'Action'}, {'id': 9648, 'n...   45527
# 7432  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...   49280
# 7433                      [{'id': 18, 'name': 'Drama'}]  111109
#
#      original_language           original_title  \
# 0                   en                Toy Story
# 1                   en                  Jumanji
# 2                   en                     Heat
# 3                   en                GoldenEye
# 4                   en         Cutthroat Island
# ...                ...                      ...
# 7429                ru                 Zolushka
# 7430                cs  Šíleně smutná princezna
# 7431                en          The Final Storm
# 7432                fr        L'Homme orchestre
# 7433                tl      Siglo ng Pagluluwal
#
#                                                overview  popularity  \
# 0     Led by Woody, Andy's toys live happily in his ...   21.946943
# 1     When siblings Judy and Peter discover an encha...   17.015539
# 2     Obsessive master thief, Neil McCauley leads a ...   17.924927
# 3     James Bond must unmask the mysterious head of ...   14.686036
# 4     Morgan Adams and her slave, William Shaw, are ...    7.284477
# ...                                                 ...         ...
# 7429  Masha Krapivina - is yet beautiful, and not th...    0.803588
# 7430                                 No overview found.    0.375001
# 7431  A stranger named Silas flees from a devastatin...    1.270832
# 7432  A band-leader has arranged seven chairs for th...    1.109068
# 7433  An artist struggles to finish his work while a...    0.178241
#
#                                    production_companies  \
# 0        [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1     [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2     [{'name': 'Regency Enterprises', 'id': 508}, {...
# 3     [{'name': 'United Artists', 'id': 60}, {'name'...
# 4     [{'name': 'Le Studio Canal+', 'id': 183}, {'na...
# ...                                                 ...
# 7429  [{'name': 'Channel One Russia', 'id': 1039}, {...
# 7430  [{'name': 'Filmové Studio Barrandov', 'id': 19...
# 7431  [{'name': 'Boll Kino Beteiligungs GmbH & Co. K...
# 7432       [{'name': 'Star Film Company', 'id': 45867}]
# 7433             [{'name': 'Sine Olivia', 'id': 19653}]
#
#                                    production_countries release_date  \
# 0     [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2     [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 3     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   1995-11-16
# 4     [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   1995-12-22
# ...                                                 ...          ...
# 7429           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2012-02-14
# 7430   [{'iso_3166_1': 'CZ', 'name': 'Czech Republic'}]   1968-06-07
# 7431  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   2010-01-01
# 7432           [{'iso_3166_1': 'FR', 'name': 'France'}]   1900-01-01
# 7433      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17
#
#           revenue  runtime                                   spoken_languages  \
# 0     373554033.0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1     262797249.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2     187436818.0    170.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 3     352194034.0    130.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4      10017322.0    119.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# ...           ...      ...                                                ...
# 7429          0.0     91.0           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 7430          0.0     73.0             [{'iso_639_1': 'cs', 'name': 'Český'}]
# 7431          0.0     92.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 7432          0.0      1.0       [{'iso_639_1': 'xx', 'name': 'No Language'}]
# 7433          0.0    360.0                  [{'iso_639_1': 'tl', 'name': ''}]
#
#                         title  vote_average  vote_count    rating
# 0                   Toy Story           7.7      5415.0  3.598930
# 1                     Jumanji           6.9      2413.0  3.760163
# 2                        Heat           7.7      1886.0  3.905544
# 3                   GoldenEye           6.6      1194.0  2.740334
# 4            Cutthroat Island           5.7       137.0  3.710181
# ...                       ...           ...         ...       ...
# 7429               Cinderella           4.6         6.0  3.795053
# 7430  Šíleně smutná princezna           6.1         4.0  3.126140
# 7431          The Final Storm           3.7        11.0  2.791667
# 7432         The One-Man Band           6.5        22.0  3.390625
# 7433      Century of Birthing           9.0         3.0  2.583333
#
# [7434 rows x 20 columns]
