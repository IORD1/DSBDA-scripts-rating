# %%
import pandas as pd

# %%
df = pd.read_csv("movie_data.csv")
dfr = pd.read_csv("rating_mean.csv")
# Out:
# /tmp/ipykernel_21148/3464219807.py:1: DtypeWarning: Columns (1,2,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("movie_data.csv")

# %%
df.head(2)
# Out:
#    Unnamed: 0  adult budget  \
# 0           0  False      0
# 1           1  False      0
#
#                                               genres  id original_language  \
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...   2                fi
# 1  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...   3                fi
#
#          original_title                                           overview  \
# 0                 Ariel  Taisto Kasurinen is a Finnish coal miner whose...
# 1  Varjoja paratiisissa  An episode in the life of Nikander, a garbage ...
#
#   popularity                               production_companies  ... runtime  \
# 0   3.860491  [{'name': 'Villealfa Filmproduction Oy', 'id':...  ...      69
# 1    2.29211  [{'name': 'Villealfa Filmproduction Oy', 'id':...  ...      76
#
#                                     spoken_languages tagline  \
# 0  [{'iso_639_1': 'fi', 'name': 'suomi'}, {'iso_6...     NaN
# ...

# %%
dfr.head(2)
# Out:
#    movieId    rating
# 0        1  3.872470
# 1        2  3.401869

# %%
dfr.shape
# Out:
# (9066, 2)

# %%
df.shape
# Out:
# (45466, 23)

# %%
# dfrlong = pd.read_csv("datasets/ratings.csv")

# %%
dfrlong.head(2)
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435

# %%
dfrlong.shape
# Out:
# (26024289, 4)

# %%
dfrmean = dfrlong.groupby("movieId")["rating"].mean()

# %%
dfrmean
# Out:
# movieId
# 1         3.888157
# 2         3.236953
# 3         3.175550
# 4         2.875713
# 5         3.079565
#             ...
# 176267    4.000000
# 176269    3.500000
# 176271    5.000000
# 176273    1.000000
# 176275    3.000000
# Name: rating, Length: 45115, dtype: float64

# %%
dfrmean.shape
# Out:
# (45115,)

# %%
dfrmean.to_csv('rating_mean_all.csv')

# %%
df.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.head(2)
#
# NameError: name 'df' is not defined

# %%
dfr_long = pd.read_csv("rating_mean_all.csv")

# %%
dfr_long.shape
# Out:
# (45115, 2)

# %%
df.shape
# Out:
# (45466, 19)

# %%
dfr_long.head(2)
# Out:
#    movieId    rating
# 0        1  3.888157
# 1        2  3.236953

# %%
df.head(1)
# Out:
#    Unnamed: 0  adult    budget  \
# 0           0  False  30000000
#
#                                               genres   id original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...  862                en
#
#   original_title                                           overview  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...
#
#   popularity                            production_companies  \
# 0  21.946943  [{'name': 'Pixar Animation Studios', 'id': 3}]
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
#
#        revenue  runtime                          spoken_languages tagline  \
# 0  373554033.0     81.0  [{'iso_639_1': 'en', 'name': 'English'}]     NaN
#
#        title  vote_average  vote_count
# 0  Toy Story           7.7      5415.0

# %%
df.rename(columns = {'id':'movieId'}, inplace = True)

# %%
df.head(1)
# Out:
#    Unnamed: 0  adult    budget  \
# 0           0  False  30000000
#
#                                               genres movieId  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
#
#   original_language original_title  \
# 0                en      Toy Story
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
#
#                              production_companies  \
# 0  [{'name': 'Pixar Animation Studios', 'id': 3}]
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
#
#        revenue  runtime                          spoken_languages tagline  \
# 0  373554033.0     81.0  [{'iso_639_1': 'en', 'name': 'English'}]     NaN
#
#        title  vote_average  vote_count
# 0  Toy Story           7.7      5415.0

# %%
df.sort_values('movieId',inplace=True)

# %%
df
# Out:
#        Unnamed: 0  adult   budget  \
# 2429         2429  False  1350000
# 13609       13609  False        0
# 4435         4435  False        0
# 17451       17451  False        0
# 36946       36946  False        0
# ...           ...    ...      ...
# 25652       25652  False        0
# 3767         3767  False        0
# 12549       12549  False        0
# 25079       25079  False        0
# 13106       13106  False        0
#
#                                                   genres movieId  \
# 2429   [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...     100
# 13609  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   10000
# 4435   [{'id': 35, 'name': 'Comedy'}, {'id': 878, 'na...   10001
# 17451  [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'n...  100010
# 36946                      [{'id': 18, 'name': 'Drama'}]  100017
# ...                                                  ...     ...
# 25652                     [{'id': 35, 'name': 'Comedy'}]   99946
# ...

# %%
dfr_long
# Out:
#        movieId    rating
# 0            1  3.888157
# 1            2  3.236953
# 2            3  3.175550
# 3            4  2.875713
# 4            5  3.079565
# ...        ...       ...
# 45110   176267  4.000000
# 45111   176269  3.500000
# 45112   176271  5.000000
# 45113   176273  1.000000
# 45114   176275  3.000000
#
# [45115 rows x 2 columns]

# %%
# df_new = pd.merge(df, dfr_long, on="movieId")

# %%
df.dtypes
# Out:
# Unnamed: 0                int64
# adult                    object
# budget                   object
# genres                   object
# movieId                  object
# original_language        object
# original_title           object
# overview                 object
# popularity               object
# production_companies     object
# production_countries     object
# release_date             object
# revenue                 float64
# runtime                 float64
# spoken_languages         object
# tagline                  object
# title                    object
# vote_average            float64
# vote_count              float64
# dtype: object

# %%
dfr_long.dtypes
# Out:
# movieId      int64
# rating     float64
# dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df = df.astype({'movieId':'int64'})
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:6226, in NDFrame.astype(self, dtype, copy, errors)
#    6224             res_col = col.copy() if copy else col
#    6225         else:
# -> 6226             res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    6227         results.append(res_col)
#    6229 elif is_extension_array_dtype(dtype) and self.ndim > 1:
#    6230     # GH 18099/22869: columnwise conversion to extension dtype
#    6231     # GH 24704: use iloc to handle duplicate column names
#    6232     # TODO(EA2D): special case not needed with 2D EAs
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
# ...
