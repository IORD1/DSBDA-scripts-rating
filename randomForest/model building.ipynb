# %%
import pandas as pd
import pickle

# %%
df = pd.read_csv("movies_credits.csv")

# %%
with open('randome_f_numeric_revenue' , 'rb') as f:
    lr = pickle.load(f)
# Out:
# C:\Users\Shubham\anaconda3\lib\site-packages\sklearn\base.py:310: UserWarning: Trying to unpickle estimator DecisionTreeRegressor from version 1.2.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\Shubham\anaconda3\lib\site-packages\sklearn\base.py:310: UserWarning: Trying to unpickle estimator RandomForestRegressor from version 1.2.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
df
# Out:
#        movie_id  actor_1_gender  actor_2_gender      actor_1_name  \
# 0           862               2               2         Tom Hanks
# 1          8844               2               2    Robin Williams
# 2         15602               2               2    Walter Matthau
# 3         31357               1               1   Whitney Houston
# 4         11862               2               1      Steve Martin
# ...         ...             ...             ...               ...
# 40392    289923               2               1        Monty Bane
# 40393    222848               1               0        Lisa Boyle
# 40394     30840               2               1    Patrick Bergin
# 40395     67758               1               2     Erika Eleniak
# 40396    227506               2               1  Iwan Mosschuchin
#
#             actor_2_name  director_gender     director_name  Unnamed: 0.1  \
# 0              Tim Allen                2     John Lasseter             0
# ...

# %%
df.isnull().sum()
# Out:
# movie_id                0
# actor_1_gender          0
# actor_2_gender          0
# actor_1_name            0
# actor_2_name            0
# director_gender         0
# director_name           0
# Unnamed: 0.1            0
# Unnamed: 0              0
# adult                   0
# budget                  0
# genres                  0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %%
df.dtypes
# Out:
# movie_id                  int64
# actor_1_gender            int64
# actor_2_gender            int64
# actor_1_name             object
# actor_2_name             object
# director_gender           int64
# director_name            object
# Unnamed: 0.1              int64
# Unnamed: 0               object
# adult                      bool
# budget                    int64
# genres                   object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                   int64
# runtime                   int64
# spoken_languages         object
# title                    object
# vote_average            float64
# vote_count                int64
# dtype: object

# %%
df.describe()
# Out:
#             movie_id  actor_1_gender  actor_2_gender  director_gender  \
# count   40397.000000    40397.000000    40397.000000     40397.000000
# mean    99952.152091        1.348442        1.171770         1.247419
# std    108173.310677        0.804442        0.806344         0.949148
# min         2.000000        0.000000        0.000000         0.000000
# 25%     24003.000000        1.000000        0.000000         0.000000
# 50%     53407.000000        2.000000        1.000000         2.000000
# 75%    134632.000000        2.000000        2.000000         2.000000
# max    469172.000000        2.000000        2.000000         2.000000
#
#        Unnamed: 0.1        budget    popularity       revenue       runtime  \
# count  40397.000000  4.039700e+04  40397.000000  4.039700e+04  40397.000000
# mean   21818.545486  4.736271e+06      3.222958  1.257198e+07     97.474045
# std    13067.412398  1.838601e+07      6.293955  6.802745e+07     33.664807
# ...

# %%
df.dtypes
for x in df:
    if df[x].dtypes == "int64":
        df[x] = df[x].astype(float)
        print (df[x].dtypes)
# Out:
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64

# %%
df2 = df.select_dtypes(exclude=['object'])

# %%
df2=df2.fillna(df.mean())

# %%
df2
# Out:
#           movie_id  actor_1_gender  actor_2_gender  director_gender  \
# 0         862.0000          2.0000          2.0000           2.0000
# 1       8,844.0000          2.0000          2.0000           2.0000
# 2      15,602.0000          2.0000          2.0000           2.0000
# 3      31,357.0000          1.0000          1.0000           2.0000
# 4      11,862.0000          2.0000          1.0000           2.0000
# ...            ...             ...             ...              ...
# 40392 289,923.0000          2.0000          1.0000           2.0000
# 40393 222,848.0000          1.0000          0.0000           2.0000
# 40394  30,840.0000          2.0000          1.0000           2.0000
# 40395  67,758.0000          1.0000          2.0000           2.0000
# 40396 227,506.0000          2.0000          1.0000           0.0000
#
#        Unnamed: 0.1  adult          budget  popularity          revenue  \
# 0            0.0000  False 30,000,000.0000     21.9469 373,554,033.0000
# ...

# %%
df2 = df2[df2.revenue != 0.0000]

# %%
df2 = df2.drop(['movie_id'], axis=1)

# %%
df2["adult"] = df["adult"].astype(int)

# %%
df2.dtypes
# Out:
# actor_1_gender     float64
# actor_2_gender     float64
# director_gender    float64
# Unnamed: 0.1       float64
# adult                int32
# budget             float64
# popularity         float64
# revenue            float64
# runtime            float64
# vote_average       float64
# vote_count         float64
# dtype: object

# %%
df2['adult'].unique()
# Out:
# array([0])

# %%
df3 = df2[['actor_1_gender','actor_2_gender','director_gender','budget','runtime']].copy()

# %%
x = df2.drop(['Unnamed: 0.1','revenue'],axis=1)

# %%
y = df2['revenue']

# %%
x = df3

# %%
print(y.mean())
# Out:
# 69533161.87541074

# %%
x
# Out:
#        actor_1_gender  actor_2_gender  director_gender          budget  \
# 0              2.0000          2.0000           2.0000 30,000,000.0000
# 1              2.0000          2.0000           2.0000 65,000,000.0000
# 3              1.0000          1.0000           2.0000 16,000,000.0000
# 4              2.0000          1.0000           2.0000          0.0000
# 5              2.0000          2.0000           2.0000 60,000,000.0000
# ...               ...             ...              ...             ...
# 40339          0.0000          0.0000           0.0000          0.0000
# 40352          0.0000          0.0000           2.0000          0.0000
# 40360          0.0000          2.0000           0.0000    800,000.0000
# 40362          2.0000          0.0000           1.0000  2,000,000.0000
# 40368          2.0000          2.0000           0.0000  5,000,000.0000
#
#        runtime
# 0      81.0000
# 1     104.0000
# 3     127.0000
# 4     106.0000
# 5     170.0000
# ...        ...
# ...

# %%
y= y.replace(0.0,12571978)

# %%
y
# Out:
# 0       373,554,033.0000
# 1       262,797,249.0000
# 3        81,452,156.0000
# 4        76,578,911.0000
# 5       187,436,818.0000
#               ...
# 40339       320,395.0000
# 40352        50,656.0000
# 40360     1,328,612.0000
# 40362     1,268,793.0000
# 40368     1,413,000.0000
# Name: revenue, Length: 7304, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
X_train
# Out:
#        actor_1_gender  actor_2_gender  director_gender          budget  \
# 21171          2.0000          1.0000           2.0000 60,000,000.0000
# 14353          2.0000          2.0000           2.0000 45,000,000.0000
# 2417           1.0000          2.0000           0.0000  1,453,000.0000
# 13999          2.0000          2.0000           2.0000 26,000,000.0000
# 4524           2.0000          2.0000           2.0000 45,000,000.0000
# ...               ...             ...              ...             ...
# 16123          2.0000          2.0000           2.0000 36,000,000.0000
# 8379           1.0000          0.0000           2.0000          0.0000
# 3460           2.0000          2.0000           2.0000          0.0000
# 5946           2.0000          1.0000           2.0000          0.0000
# 6347           2.0000          2.0000           2.0000          0.0000
#
#        runtime
# 21171 105.0000
# 14353 128.0000
# 2417  111.0000
# 13999 104.0000
# 4524  122.0000
# ...        ...
# ...

# %%
y_train
# Out:
# 21171    50,549,107.0000
# 14353    60,222,298.0000
# 2417      5,638,000.0000
# 13999    43,318,349.0000
# 4524    104,876,233.0000
#               ...
# 16123    83,160,734.0000
# 8379         39,388.0000
# 3460     39,768,000.0000
# 5946     29,888,235.0000
# 6347     10,878,107.0000
# Name: revenue, Length: 5112, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor = RandomForestRegressor(n_estimators = 1000, random_state = 1000)

# %%
x
# Out:
#        actor_1_gender  actor_2_gender  director_gender          budget  \
# 0              2.0000          2.0000           2.0000 30,000,000.0000
# 1              2.0000          2.0000           2.0000 65,000,000.0000
# 3              1.0000          1.0000           2.0000 16,000,000.0000
# 4              2.0000          1.0000           2.0000          0.0000
# 5              2.0000          2.0000           2.0000 60,000,000.0000
# ...               ...             ...              ...             ...
# 40339          0.0000          0.0000           0.0000          0.0000
# 40352          0.0000          0.0000           2.0000          0.0000
# 40360          0.0000          2.0000           0.0000    800,000.0000
# 40362          2.0000          0.0000           1.0000  2,000,000.0000
# 40368          2.0000          2.0000           0.0000  5,000,000.0000
#
#        runtime
# 0      81.0000
# 1     104.0000
# 3     127.0000
# 4     106.0000
# 5     170.0000
# ...        ...
# ...

# %%
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=1000, random_state=1000)

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([2.74051509e+06, 9.84930808e+06, 4.12127029e+05, ...,
#        2.37185989e+08, 2.45073099e+07, 1.89904649e+07])

# %%
pd.options.display.float_format = '{:,.4f}'.format

# %%
# accuracy_score(y_test, y_pred)

# %%
regressor.score(X_test,y_test)
# Out:
# 0.41145147545546557

# %%
dff=pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})
dff
# Out:
#                 Actual        Predicted
# 20363   1,600,000.0000   2,755,647.0561
# 27732     187,112.0000   8,775,035.7200
# 1965   40,471,663.0000     410,783.6755
# 27295 112,156,811.0000 111,666,611.9000
# 10524 660,940,780.0000 159,304,532.0200
# ...                ...              ...
# 9247   10,000,000.0000  62,365,213.2818
# 18564  32,726,956.0000  47,837,712.4525
# 16862  75,450,437.0000 228,580,380.6250
# 18984 116,980,662.0000  23,587,373.0415
# 1904   50,752,337.0000  16,705,071.5707
#
# [2192 rows x 2 columns]

# %%
from sklearn import metrics
import numpy as np
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 7018374.450581931
# Mean Squared Error: 911311713168945.0
# Root Mean Squared Error: 30187939.86294767

# %%
# Calculate the absolute errors
errors = abs(y_pred - y_test)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')

# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / y_test)
#mape : 
print("mape " ,np.mean(mape))
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Mean Absolute Error: 7018374.45 degrees.
# mape  433834.94416786445
# Accuracy: -433734.94 %.

# %%
errors = abs(y_pred - y_test)
mape = 100 * np.mean(errors / y_test)
accuracy = 100 - mape

# %%
print(accuracy)
# Out:
# -433734.94416786445

# %%
import pickle

# %%
pickle.dump(regressor, open('randome_f_numeric_revenue', "wb"))

# %%
loaded_model = pickle.load(open('randome_f_numeric_revenue', "rb"))

# %%
from sklearn.metrics import accuracy_score

# %%
regressor.predict([[2.0000,2.0000,2.0000,60000000.0000,170.0000]])
# Out:
# array([2.24712803e+08])
